# %% [markdown]
# # Retrieve pixel coordinates from a GeoTIFF file
# This tutorial shows how to retrieve pixel coordinates (latitudes, longitudes) from a GeoTIFF subset file from the [ORNL DAAC's Global Subset Order](https://modis.ornl.gov/globalsubset/).
#
# We will use an example GeoTIFF file, `MYD17A2H.A2022185.h12v04.061.2022195050454_Gpp_500m.tif`, in the `data` folder.

# %%
import rioxarray
from os import path

subset_tif = 'MYD17A2H.A2022185.h12v04.061.2022195050454_Gpp_500m.tif'
ds = rioxarray.open_rasterio(path.join('data', subset_tif), parse_coordinates=True)
ds
# Out:
# <xarray.DataArray (band: 1, y: 181, x: 241)>
# array([[[32766, 32766, ..., 32766, 32766],
#         [32766, 32766, ..., 32766, 32766],
#         ...,
#         [32766, 32766, ...,   568,   568],
#         [32766, 32766, ...,   568,   573]]], dtype=int32)
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -6.454e+06 -6.453e+06 ... -6.343e+06 -6.343e+06
#   * y            (y) float64 5.033e+06 5.032e+06 ... 4.95e+06 4.949e+06
#     spatial_ref  int64 0
# Attributes:
#     _FillValue:    -9999999.0
#     scale_factor:  1.0
#     add_offset:    0.0

# %% [markdown]
# As you see in the `spatial_ref` above, the data array `ds` is in the MODIS Sinusoidal projection. Let's print its Coordinate Reference System.

# %%
ds.rio.crs
# Out:
# CRS.from_wkt('PROJCS["unnamed",GEOGCS["unnamed ellipse",DATUM["unknown",SPHEROID["unnamed",6371007.181,0]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Sinusoidal"],PARAMETER["longitude_of_center",0],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]')

# %% [markdown]
# Now we can reproject the `ds` from Sinusoidal to WGS84 and print latitude and longitude values.

# %%
ds_wgs84 = ds.rio.reproject("EPSG:4326")
# print longitudes
ds_wgs84.x
# Out:
# <xarray.DataArray 'x' (x: 288)>
# array([-82.457672, -82.449064, -82.440457, ..., -80.004646, -79.996039,
#        -79.987432])
# Coordinates:
#   * x            (x) float64 -82.46 -82.45 -82.44 -82.43 ... -80.0 -80.0 -79.99
#     spatial_ref  int64 0
# Attributes:
#     axis:           X
#     long_name:      longitude
#     standard_name:  longitude
#     units:          degrees_east

# %%
# print latitudes
ds_wgs84.y
# Out:
# <xarray.DataArray 'y' (y: 88)>
# array([45.258196, 45.249589, 45.240982, 45.232375, 45.223768, 45.215161,
#        45.206554, 45.197947, 45.18934 , 45.180732, 45.172125, 45.163518,
#        45.154911, 45.146304, 45.137697, 45.12909 , 45.120483, 45.111876,
#        45.103269, 45.094661, 45.086054, 45.077447, 45.06884 , 45.060233,
#        45.051626, 45.043019, 45.034412, 45.025805, 45.017197, 45.00859 ,
#        44.999983, 44.991376, 44.982769, 44.974162, 44.965555, 44.956948,
#        44.948341, 44.939734, 44.931126, 44.922519, 44.913912, 44.905305,
#        44.896698, 44.888091, 44.879484, 44.870877, 44.86227 , 44.853662,
#        44.845055, 44.836448, 44.827841, 44.819234, 44.810627, 44.80202 ,
#        44.793413, 44.784806, 44.776199, 44.767591, 44.758984, 44.750377,
#        44.74177 , 44.733163, 44.724556, 44.715949, 44.707342, 44.698735,
#        44.690127, 44.68152 , 44.672913, 44.664306, 44.655699, 44.647092,
#        44.638485, 44.629878, 44.621271, 44.612664, 44.604056, 44.595449,
#        44.586842, 44.578235, 44.569628, 44.561021, 44.552414, 44.543807,
#        44.5352  , 44.526592, 44.517985, 44.509378])
# Coordinates:
#   * y            (y) float64 45.26 45.25 45.24 45.23 ... 44.54 44.53 44.52 44.51
#     spatial_ref  int64 0
# Attributes:
#     axis:           Y
#     long_name:      latitude
#     standard_name:  latitude
#     units:          degrees_north
